# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('cleaned_dataset.csv')
df.head()
# Out:
#    employee_id         department     region   education gender  \
# 0         1264            Finance   region_7  Bachelor's      m
# 1        18375            Finance   region_7  Bachelor's      m
# 2        34167         Operations   region_2  Bachelor's      m
# 3        14280         Technology  region_29  Bachelor's      m
# 4        24219  Sales & Marketing  region_26  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0               other                1   31                   3.0
# 1               other                1   31                   5.0
# 2               other                1   53                   3.0
# 3               other                1   27                   2.0
# 4               other                1   44                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  3              0            0                  62
# ...

# %% [markdown]
# numerical and ctegorical values list

# %%
num_features=[features for features in df.columns if df[features].dtype!='O']
cat_features=[features for features in df.columns if df[features].dtype=='O']
for features in cat_features:
    print(df[features].value_counts())
    print('='*20)
# Out:
# department
# Sales & Marketing    10088
# Operations            6778
# Procurement           4338
# Technology            4238
# Analytics             3217
# Finance               1552
# HR                    1436
# Legal                  619
# R&D                    618
# Name: count, dtype: int64
# ...
# region
# region_2     7448
# region_22    3850
# region_7     2905
# region_15    1734
# region_13    1573
# region_26    1335
# region_31    1132
# region_4     1022
# region_27    1003
# region_16     877
# region_28     805
# region_11     777
# region_23     703
# region_29     599
# region_19     542
# region_32     539
# region_20     513
# region_25     506
# region_14     487
# region_17     483
# region_5      471
# region_6      405
# region_8      398
# region_30     395
# region_10     376
# region_1      336
# region_24     309
# region_12     293
# region_9      269
# region_21     258
# region_3      194
# region_34     170
# region_33     155
# region_18      22
# ...

# %%
import matplotlib.pyplot as plt
for feature in num_features:
    if feature !='Newsletter_Subscription':
        plt.boxplot(df[feature])
        plt.xlabel(feature)
        plt.show()

# %% [markdown]
# ### Univariate analysis

# %%
sns.histplot(x='age',data=df,kde=True,bins=20)
plt.show()

# %%
sns.histplot(x='avg_training_score',data=df,kde=True,bins=15)
plt.show()

# %%
sns.histplot(x='length_of_service',data=df,kde=True,bins=20)
plt.show()

# %% [markdown]
# ### Report
# ->Length_of_service is right skewed so there might be a poblem with outliers
#
# ->Age is mostly normally distributed
#
# ->Avg_training is almost randomy distributed

# %% [markdown]
# ### Bi variate analysis

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='department',data=df,y='age',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->Operations department and Procurment department people are almost of same age
#
# ->whereas in Operations more number of promotions occured
#
# ->Finance people are younger and less likely promoted

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='department',data=df,y='previous_year_rating')
# Out:
# <Axes: xlabel='department', ylabel='previous_year_rating'>

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='department',data=df,y='previous_year_rating',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->If previous year rating is <3.0 then less likely promoted
#
# ->If >=3.5 more likely be promoted

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='department',data=df,y='length_of_service',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->Operations people are having high length_of_service and highly promoted
#
# ->Where as Finance people are less_serviced and less likely promoted

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='region',data=df,y='age',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->Region is highly populated

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='education',data=df,y='previous_year_rating',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->If the person having previus year experience < 3.0 less likely promoted
#
# ->If previous year expericance >=3.5 more likely promoted

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='education',data=df,y='avg_training_score',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->If the person having previus year experience < 65 less likely promoted
#
# ->If previous year expericance >=65 more likely promoted

# %%
df.head()
# Out:
#    employee_id         department     region   education gender  \
# 0         1264            Finance   region_7  Bachelor's      m
# 1        18375            Finance   region_7  Bachelor's      m
# 2        34167         Operations   region_2  Bachelor's      m
# 3        14280         Technology  region_29  Bachelor's      m
# 4        24219  Sales & Marketing  region_26  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0               other                1   31                   3.0
# 1               other                1   31                   5.0
# 2               other                1   53                   3.0
# 3               other                1   27                   2.0
# 4               other                1   44                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  3              0            0                  62
# ...

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='gender',data=df,y='previous_year_rating',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->If the person having previus year rating < 3.5 less likely promoted
#
# ->If previous year rating >=3.5 more likely promoted

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='gender',data=df,y='avg_training_score',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->irrespectve of the gnder if avg_training_score <65 not promoted

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='recruitment_channel',data=df,y='age',hue='is_promoted')
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='recruitment_channel',data=df,y='previous_year_rating',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->Even the reffered candidates having the previous year rating above 3.5 htere is no moch difference in promotion

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='recruitment_channel',data=df,y='avg_training_score',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->If the person having previus year experience < 65 less likely promoted
#
# ->If previous year expericance >=65 more likely promoted

# %%
sns.barplot(x='no_of_trainings',y='previous_year_rating',data=df)
plt.show()

# %%
sns.lineplot(x='no_of_trainings',y='previous_year_rating',data=df)
plt.show()

# %% [markdown]
# ### Report
# ->As the number of trainning is less then the previous yea rating might be more
#
# might be due to a person with a single training can work more effectively onthat work which he ws trained

# %%
sns.lineplot(x='age',y='no_of_trainings',data=df)
plt.show()

# %% [markdown]
# ### Report
# ->People during the age of 20-30 getting more number of training

# %%
sns.lineplot(x='age',y='length_of_service',data=df)
plt.show()

# %% [markdown]
# ### Report
# ->as age increases length of service increases

# %%
sns.lineplot(x='age',y='avg_training_score',data=df)
plt.show()

# %% [markdown]
# ### Report
# ->People in their 20-30's getting more avg score as they are attending for more number of trainings

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='KPIs_met >80%',data=df,y='length_of_service',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->If the KPI met is 0 then even having more length of service there is less likely promoted
#
# ->If KPI met is 1 then even having length of service there is more likely promoted

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='KPIs_met >80%',data=df,y='avg_training_score',hue='is_promoted')
plt.show()

# %% [markdown]
# ### Report
# ->If the KPI met is 0 then having more avg_training_score there is more likely promoted
#
# ->If the KPI met is 1 then having more avg_training_score there is more likely promoted

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='is_promoted',data=df,y='previous_year_rating')
plt.show()

# %% [markdown]
# ### Report
# ->If the previous year rating above 3.5 more likely promoted

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='is_promoted',data=df,y='avg_training_score')
plt.show()

# %% [markdown]
# ### Report
# ->Ang training score more than 63 then more likely promoted

# %%
df_dic=df['department'].value_counts().to_dict()
import matplotlib.pyplot as plt
# Plotting the pie chart
plt.figure(figsize=(16, 8))
plt.pie(df_dic.values(), labels=df_dic.keys(), autopct='%1.1f%%', startangle=10,shadow=True,frame=True,normalize=True)
plt.title('Distribution of Departments')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Report
# ->sales and marketing are the Most destributed among departments

# %%
df_dic=df['education'].value_counts().to_dict()
import matplotlib.pyplot as plt
# Plotting the pie chart
plt.figure(figsize=(16, 8))
plt.pie(df_dic.values(), labels=df_dic.keys(), autopct='%1.1f%%', startangle=10,shadow=True,frame=True,normalize=True)
plt.title('Distribution of education')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Report
# ->most of the people are fro bachelor's backgound

# %%
df_dic=df['gender'].value_counts().to_dict()
import matplotlib.pyplot as plt
# Plotting the pie chart
plt.figure(figsize=(16, 8))
plt.pie(df_dic.values(), labels=df_dic.keys(), autopct='%1.1f%%', startangle=10,shadow=True,frame=True,normalize=True)
plt.title('Distribution of gender')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Report
# ->Most employess are males

# %%
df_dic=df['recruitment_channel'].value_counts().to_dict()
import matplotlib.pyplot as plt
# Plotting the pie chart
plt.figure(figsize=(16, 8))
plt.pie(df_dic.values(), labels=df_dic.keys(), autopct='%1.1f%%', startangle=10,shadow=True,frame=True,normalize=True)
plt.title('Distribution of recruitment_channel')
plt.axis('equal')
plt.show()

# %%
df_dic=df['previous_year_rating'].value_counts().to_dict()
import matplotlib.pyplot as plt
# Plotting the pie chart
plt.figure(figsize=(16, 8))
plt.pie(df_dic.values(), labels=df_dic.keys(), autopct='%1.1f%%', startangle=10,shadow=True,frame=True,normalize=True)
plt.title('Distribution of previous_year_rating')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Report
# ->41.4% people got 3.0 previous year rating

# %%
df_dic=df['KPIs_met >80%'].value_counts().to_dict()
import matplotlib.pyplot as plt
# Plotting the pie chart
plt.figure(figsize=(16, 8))
plt.pie(df_dic.values(), labels=df_dic.keys(), autopct='%1.1f%%', startangle=10,shadow=True,frame=True,normalize=True)
plt.title('Distribution of KPIs_met >80%')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Report
# ->64.6% people has <80% KPI's

# %%
df_dic=df['awards_won?'].value_counts().to_dict()
import matplotlib.pyplot as plt
# Plotting the pie chart
plt.figure(figsize=(16, 8))
plt.pie(df_dic.values(), labels=df_dic.keys(), autopct='%1.1f%%', startangle=10,shadow=True,frame=True,normalize=True)
plt.title('Distribution of awards_won?')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Report
# ->only 2.4% percent people won awards

# %%
df_dic=df['is_promoted'].value_counts().to_dict()
import matplotlib.pyplot as plt
# Plotting the pie chart
plt.figure(figsize=(16, 8))
plt.pie(df_dic.values(), labels=df_dic.keys(), autopct='%1.1f%%', startangle=10,shadow=True,frame=True,normalize=True)
plt.title('Distribution of is_promoted')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Report
# ->only 8.8% percent people are get promoted

# %% [markdown]
# ### Final Report
# ->Length_of_service is right skewed so there might be a poblem with outliers
#
# ->Age is mostly normally distributed
#
# ->Avg_training is almost randomy distributed
#
# ->Operations more number of promotions occured
#
# ->Finance people are younger and less likely promoted
#
# ->If previous year rating is <3.0 then less likely promoted
#
# ->Operations people are having high length_of_service and highly promoted
#
# ->Where as Finance people are less_serviced and less likely promoted
#
# ->If previous year expericance >=65 more likely promoted
#
# ->irrespectve of the gnder if avg_training_score <65 not promoted
#
# ->As the number of trainning is less then the previous yea rating might be more
#
# might be due to a person with a single training can work more effectively onthat work which he ws trained
#
# ->as age increases length of service increases
#
# ->People during the age of 20-30 getting more number of training
#
# ->Ang training score more than 63 then more likely promoted
#
# ->sales and marketing are the Most destributed among departments
#
# ->most of the people are fro bachelor's backgound
#
# ->Most employess are males
#
# ->41.4% people got 3.0 previous year rating
#
# ->only 2.4% percent people won awards
#
# ->only 8.8% percent people are get promoted
#
# ->We can remove Region,Employee ID,Length_of service(as age and length_of_service. Why Only Length_of_service removed?->because it has more outliers)

# %%
df.head()
# Out:
#    employee_id         department     region   education gender  \
# 0         1264            Finance   region_7  Bachelor's      m
# 1        18375            Finance   region_7  Bachelor's      m
# 2        34167         Operations   region_2  Bachelor's      m
# 3        14280         Technology  region_29  Bachelor's      m
# 4        24219  Sales & Marketing  region_26  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0               other                1   31                   3.0
# 1               other                1   31                   5.0
# 2               other                1   53                   3.0
# 3               other                1   27                   2.0
# 4               other                1   44                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  3              0            0                  62
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-2f6f6606aa2c> in <module>
# ----> 1 df.corr()
#
# c:\Users\srika\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# c:\Users\srika\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...
